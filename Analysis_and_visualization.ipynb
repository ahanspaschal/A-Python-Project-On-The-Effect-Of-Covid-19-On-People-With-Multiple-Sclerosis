# %%
#Importing all necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder

# %%
#Reading data into a DataFrame
df = pd.read_csv('GDSI_OpenDataset_Final.csv')
df
# Out:
#      secret_name report_source  age_in_cat     bmi_in_cat2  \
# 0         C_1005    clinicians           1             NaN
# 1         C_1008    clinicians           1             NaN
# 2         C_1037    clinicians           1             NaN
# 3         C_1039    clinicians           1             NaN
# 4         C_1061    clinicians           1             NaN
# ...          ...           ...         ...             ...
# 1136       P_916      patients           2  not_overweight
# 1137       P_919      patients           2  not_overweight
# 1138       P_953      patients           2  not_overweight
# 1139       P_954      patients           2  not_overweight
# 1140       P_992      patients           2  not_overweight
#
#      covid19_admission_hospital covid19_confirmed_case covid19_diagnosis  \
# 0                            no                    yes         confirmed
# 1                            no                    yes         confirmed
# 2                            no                    yes         confirmed
# 3                            no                     no         suspected
# 4                           yes                     no         suspected
# ...                         ...                    ...               ...
# 1136                         no                     no     not_suspected
# 1137                         no                     no     not_suspected
# 1138                         no                     no     not_suspected
# 1139                         no                     no         suspected
# 1140                         no                     no     not_suspected
#
#      covid19_has_symptoms covid19_icu_stay covid19_outcome_recovered  ...  \
# 0                     NaN               no                       yes  ...
# 1                     yes               no                       yes  ...
# 2                     yes               no            not_applicable  ...
# 3                     yes               no            not_applicable  ...
# 4                     yes               no                       yes  ...
# ...                   ...              ...                       ...  ...
# 1136                   no               no            not_applicable  ...
# 1137                   no               no            not_applicable  ...
# 1138                   no               no            not_applicable  ...
# 1139                  yes               no            not_applicable  ...
# 1140                  yes               no            not_applicable  ...
#
#      com_chronic_kidney_disease com_chronic_liver_disease com_diabetes  \
# 0                           NaN                       NaN          NaN
# 1                           NaN                       NaN          NaN
# 2                           NaN                       NaN          NaN
# 3                           NaN                       NaN          NaN
# 4                            no                        no           no
# ...                         ...                       ...          ...
# 1136                        NaN                       NaN          NaN
# 1137                        NaN                       NaN          NaN
# 1138                        NaN                       NaN          NaN
# 1139                         no                        no           no
# 1140                        NaN                       NaN          NaN
#
#      com_hypertension com_immunodeficiency com_lung_disease com_malignancy  \
# 0                 NaN                  NaN              NaN            NaN
# 1                 NaN                  NaN              yes            NaN
# 2                 NaN                  NaN              NaN            NaN
# 3                 NaN                  NaN              NaN            NaN
# 4                 yes                   no               no             no
# ...               ...                  ...              ...            ...
# 1136              NaN                  NaN              yes            NaN
# 1137              NaN                  NaN              NaN            NaN
# 1138              NaN                  NaN              NaN            NaN
# 1139               no                   no              yes             no
# 1140              NaN                  NaN              NaN            NaN
#
#      com_neurological_neuromuscular stop_or_end_date_combined  \
# 0                               NaN                       NaN
# 1                               NaN                       NaN
# 2                               NaN                       NaN
# 3                               NaN                       NaN
# 4                                no                24/04/2020
# ...                             ...                       ...
# 1136                            NaN                18/04/2020
# 1137                            NaN                24/12/2016
# 1138                            NaN                20/04/2020
# 1139                             no                       NaN
# 1140                            NaN                13/04/2020
#
#      comorbidities_other
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 1136                 NaN
# 1137                 NaN
# 1138                 NaN
# 1139                 1.0
# 1140                 NaN
#
# [1141 rows x 47 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1141 entries, 0 to 1140
# Data columns (total 47 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   secret_name                     1141 non-null   object
#  1   report_source                   1141 non-null   object
#  2   age_in_cat                      1141 non-null   int64
#  3   bmi_in_cat2                     890 non-null    object
#  4   covid19_admission_hospital      1141 non-null   object
#  5   covid19_confirmed_case          1141 non-null   object
#  6   covid19_diagnosis               1141 non-null   object
#  7   covid19_has_symptoms            1133 non-null   object
#  8   covid19_icu_stay                1138 non-null   object
#  9   covid19_outcome_recovered       1141 non-null   object
#  10  covid19_self_isolation          1126 non-null   object
#  11  covid19_sympt_chills            248 non-null    object
#  12  covid19_sympt_dry_cough         281 non-null    object
#  13  covid19_sympt_fatigue           291 non-null    object
#  14  covid19_sympt_fever             285 non-null    object
#  15  covid19_sympt_loss_smell_taste  245 non-null    object
#  16  covid19_sympt_nasal_congestion  264 non-null    object
#  17  covid19_sympt_pain              276 non-null    object
#  18  covid19_sympt_pneumonia         228 non-null    object
#  19  covid19_sympt_shortness_breath  256 non-null    object
#  20  covid19_sympt_sore_throat       273 non-null    object
#  21  covid19_ventilation             1136 non-null   object
#  22  current_dmt                     1141 non-null   object
#  23  dmt_glucocorticoid              1071 non-null   object
#  24  edss_in_cat2                    523 non-null    float64
#  25  has_comorbidities               1141 non-null   object
#  26  pregnancy                       858 non-null    object
#  27  sex                             1141 non-null   object
#  28  year_onset                      1039 non-null   float64
#  29  ms_type2                        1141 non-null   object
#  30  current_or_former_smoker        495 non-null    object
#  31  dmt_type_overall                980 non-null    object
#  32  covid19_outcome_levels_2        1141 non-null   int64
#  33  duration_treatment_cat2         222 non-null    float64
#  34  com_cardiovascular_disease      265 non-null    object
#  35  has_comorbidities.1             1141 non-null   object
#  36  has_comorbidities.2             1141 non-null   object
#  37  com_chronic_kidney_disease      262 non-null    object
#  38  com_chronic_liver_disease       266 non-null    object
#  39  com_diabetes                    268 non-null    object
#  40  com_hypertension                277 non-null    object
#  41  com_immunodeficiency            262 non-null    object
#  42  com_lung_disease                266 non-null    object
#  43  com_malignancy                  262 non-null    object
#  44  com_neurological_neuromuscular  266 non-null    object
#  45  stop_or_end_date_combined       820 non-null    object
#  46  comorbidities_other             232 non-null    float64
# dtypes: float64(4), int64(2), object(41)
# memory usage: 419.1+ KB

# %%
#Converting date column to a datetime format
df['stop_or_end_date_combined'] = pd.to_datetime(df['stop_or_end_date_combined'])

# %%
#Handling missing values
perc_missing_data = df.isnull().sum()*100/len(df) #checking for % missing data
perc_missing_data.sort_values(ascending = False)

#filling missing values for datetime column
df['stop_or_end_date_combined'].fillna(df['stop_or_end_date_combined'].mean(), inplace=True)

col_to_drop =perc_missing_data[perc_missing_data>75].keys() #extracting columns with over 75% missing data

df.drop(col_to_drop, axis=1, inplace=True) #dropping columns with over 75% missing data

# %%
# Dropping the column with high missing rate close to threshold
df1 = df.drop(columns=['covid19_sympt_fatigue', 'secret_name'])

# %%
df1
# Out:
#      report_source  age_in_cat     bmi_in_cat2 covid19_admission_hospital  \
# 0       clinicians           1             NaN                         no
# 1       clinicians           1             NaN                         no
# 2       clinicians           1             NaN                         no
# 3       clinicians           1             NaN                         no
# 4       clinicians           1             NaN                        yes
# ...            ...         ...             ...                        ...
# 1136      patients           2  not_overweight                         no
# 1137      patients           2  not_overweight                         no
# 1138      patients           2  not_overweight                         no
# 1139      patients           2  not_overweight                         no
# 1140      patients           2  not_overweight                         no
#
#      covid19_confirmed_case covid19_diagnosis covid19_has_symptoms  \
# 0                       yes         confirmed                  NaN
# 1                       yes         confirmed                  yes
# 2                       yes         confirmed                  yes
# 3                        no         suspected                  yes
# 4                        no         suspected                  yes
# ...                     ...               ...                  ...
# 1136                     no     not_suspected                   no
# 1137                     no     not_suspected                   no
# 1138                     no     not_suspected                   no
# 1139                     no         suspected                  yes
# 1140                     no     not_suspected                  yes
#
#      covid19_icu_stay covid19_outcome_recovered covid19_self_isolation  ...  \
# 0                  no                       yes                    yes  ...
# 1                  no                       yes                    yes  ...
# 2                  no            not_applicable                    yes  ...
# 3                  no            not_applicable                    yes  ...
# 4                  no                       yes                    yes  ...
# ...               ...                       ...                    ...  ...
# 1136               no            not_applicable                    yes  ...
# 1137               no            not_applicable                     no  ...
# 1138               no            not_applicable                     no  ...
# 1139               no            not_applicable                     no  ...
# 1140               no            not_applicable                     no  ...
#
#      pregnancy     sex year_onset             ms_type2  \
# 0          NaN  female        NaN  relapsing_remitting
# 1          NaN  female        NaN  relapsing_remitting
# 2          NaN  female        NaN  relapsing_remitting
# 3          NaN  female        NaN  relapsing_remitting
# 4           no  female     2007.0  relapsing_remitting
# ...        ...     ...        ...                  ...
# 1136       NaN    male     2017.0                other
# 1137       NaN    male     2000.0       progressive_MS
# 1138       NaN    male     1996.0  relapsing_remitting
# 1139       NaN    male     2007.0  relapsing_remitting
# 1140       NaN    male     2005.0  relapsing_remitting
#
#      current_or_former_smoker                      dmt_type_overall  \
# 0                         NaN               currently on fingolimod
# 1                         NaN              currently on natalizumab
# 2                         NaN               currently on fingolimod
# 3                         NaN  currently on another drug not listed
# 4                         NaN  currently on another drug not listed
# ...                       ...                                   ...
# 1136                      yes               currently on fingolimod
# 1137                      yes           currently not using any DMT
# 1138                      NaN  currently on another drug not listed
# 1139                      NaN           currently not using any DMT
# 1140                      yes  currently on another drug not listed
#
#      covid19_outcome_levels_2  has_comorbidities.1 has_comorbidities.2  \
# 0                           0                   no                  no
# 1                           0                  yes                 yes
# 2                           0                   no                  no
# 3                           0                   no                  no
# 4                           1                  yes                 yes
# ...                       ...                  ...                 ...
# 1136                        0                  yes                 yes
# 1137                        0                   no                  no
# 1138                        0                   no                  no
# 1139                        0                  yes                 yes
# 1140                        0                   no                  no
#
#          stop_or_end_date_combined
# 0    2019-11-06 22:00:35.121951232
# 1    2019-11-06 22:00:35.121951232
# 2    2019-11-06 22:00:35.121951232
# 3    2019-11-06 22:00:35.121951232
# 4    2020-04-24 00:00:00.000000000
# ...                            ...
# 1136 2020-04-18 00:00:00.000000000
# 1137 2016-12-24 00:00:00.000000000
# 1138 2020-04-20 00:00:00.000000000
# 1139 2019-11-06 22:00:35.121951232
# 1140 2020-04-13 00:00:00.000000000
#
# [1141 rows x 25 columns]

# %%
 #Replacing the remaining categorical missing values with most frequent occuring values in each column

 imputer = SimpleImputer(strategy= 'most_frequent') #initializing imputer 

 categorical_columns = ['current_or_former_smoker', 'pregnancy', 'bmi_in_cat2', 'dmt_type_overall']
 df1[categorical_columns] = imputer.fit_transform(df1[categorical_columns])

 # For numerical 'edss_in_cat2', we use the median value for imputation
 imputer_num = SimpleImputer(strategy='median')
 df1['edss_in_cat2'] = imputer_num.fit_transform(df1[['edss_in_cat2']])

 # For very low missing rates, drop rows where any of these values are missing
 low_missing_columns = ['year_onset', 'dmt_glucocorticoid', 'covid19_self_isolation', 'covid19_has_symptoms', 
                        'covid19_ventilation', 'covid19_icu_stay', 'stop_or_end_date_combined']
 df1.dropna(subset=low_missing_columns, inplace=True)


 df1.isnull().sum() #checking for null values
# Out:
# report_source                 0
# age_in_cat                    0
# bmi_in_cat2                   0
# covid19_admission_hospital    0
# covid19_confirmed_case        0
# covid19_diagnosis             0
# covid19_has_symptoms          0
# covid19_icu_stay              0
# covid19_outcome_recovered     0
# covid19_self_isolation        0
# covid19_ventilation           0
# current_dmt                   0
# dmt_glucocorticoid            0
# edss_in_cat2                  0
# has_comorbidities             0
# pregnancy                     0
# sex                           0
# year_onset                    0
# ms_type2                      0
# current_or_former_smoker      0
# dmt_type_overall              0
# covid19_outcome_levels_2      0
# has_comorbidities.1           0
# has_comorbidities.2           0
# stop_or_end_date_combined     0
# dtype: int64

# %%
# Set the aesthetic style of the plots
sns.set(style="whitegrid")

# Creating figures for selected univariate analysis
fig, axes = plt.subplots(1, 2, figsize=(14, 6))
fig.suptitle('Selected Univariate Analysis of Key Variables')

# Histogram for year_onset
sns.histplot(data=df1, x='year_onset', bins=20, kde=True, ax=axes[0])
axes[0].set_title('Year of MS Onset Distribution')

# Bar chart for covid19_outcome_recovered
sns.countplot(data=df1, x='covid19_outcome_recovered', ax=axes[1])
axes[1].set_title('COVID-19 Recovery Outcome')

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()a

# %%
#Exploratory data analysis
#1). plotting data to show the distribution of COVID-19 hospital admissions and ICU stays.

sns.set_style("whitegrid") # Setting the style of the plots
# Checking for COVID-19 hospital admissions distribution
plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
sns.countplot(x='covid19_admission_hospital', data=df1)
plt.title('COVID-19 Hospital Admissions')
plt.xticks([0, 1], ['No', 'Yes'])

# Distribution of COVID-19 ICU stays
plt.subplot(1, 2, 2)
sns.countplot(x='covid19_icu_stay', data=df1)
plt.title('COVID-19 ICU Stays')
plt.xticks([0, 1], ['No', 'Yes'])

plt.tight_layout()
plt.show()

# %%
# Plotting data to show the relationship between MS type and COVID-19 outcomes

plt.figure(figsize=(7, 5))
sns.countplot(x='ms_type2', hue='covid19_outcome_recovered', data=df1)
plt.title('MS Type vs COVID-19 Outcome')
plt.xlabel('MS Type')
plt.legend(['Not Recovered', 'Not Applicable', 'Recovered'], title='Outcome')

plt.show()

# %%
# Impact of comorbidities on COVID-19 outcomes
plt.figure(figsize=(7, 5))
sns.countplot(x='has_comorbidities', hue='covid19_outcome_recovered', data=df1)
plt.title('Comorbidities and COVID-19 Outcomes')
plt.xlabel('Has Comorbidities')
plt.xticks([0, 1], ['Yes', 'No'])
plt.legend(['Not Recovered', 'Not Applicable', 'Recovered'], title='Outcome')

plt.show()

# %%
#Plotting the relationship between smoking status of MS patients and covid-19 severity(ICU stay)
plt.figure(figsize=(7, 5))
sns.countplot(x='current_or_former_smoker', hue='covid19_icu_stay', data=df1)
plt.title('Smoking status vs COVID-19 ICU stay')
plt.xlabel('current or former smoker')
plt.xticks([0, 1], ['No', 'Yes'])
plt.legend(['No', 'Yes'], title='ICU stay')

plt.show()

# %%
# Plot the distribution of COVID-19 outcomes
plt.figure(figsize=(10, 6))
outcome_counts = df['covid19_outcome_recovered'].value_counts(normalize=True) * 100
sns.barplot(x=outcome_counts.index, y=outcome_counts.values, palette="Blues_d")
plt.title('Distribution of COVID-19 Outcomes Among MS Patients')
plt.ylabel('Percentage of Patients')
plt.xlabel('COVID-19 Outcome')
plt.xticks([0, 1, 2], ['No', 'not_applicable', 'Yes'])
plt.show()

# %%
#checking correlation matrix of selected numerical and categorical variables.
selected_columns = ['age_in_cat', 'year_onset', 'edss_in_cat2', 'covid19_outcome_levels_2']
data_selected = df1[selected_columns]

# Compute the correlation matrix
correlation_matrix = data_selected.corr()

# Generate a heatmap for the correlation matrix
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix of Selected Numerical Variables')
plt.show()
